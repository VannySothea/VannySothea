# %% [markdown]
# <a href="https://colab.research.google.com/github/VannySothea/VannySothea/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4 + 6
# Out:
# 10

# %%
5 == 5
# Out:
# True
